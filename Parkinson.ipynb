# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from tensorflow.keras.applications.vgg16 import VGG16

# %%
# !wget https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/Parkinson_disease_detection.zip
# !unzip -qo Parkinson_disease_detection.zip
# Out:
# --2023-04-22 04:45:25--  https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/Parkinson_disease_detection.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.158.175
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.158.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8201907 (7.8M) [application/x-zip-compressed]
# Saving to: ‘Parkinson_disease_detection.zip’
#
# Parkinson_disease_d 100%[===================>]   7.82M  14.1MB/s    in 0.6s
#
# 2023-04-22 04:45:26 (14.1 MB/s) - ‘Parkinson_disease_detection.zip’ saved [8201907/8201907]

# %%
data_train = np.load('Parkinson_disease_detection/train_set.npz', allow_pickle=True)
x_train = data_train['arr_0']
y_train = data_train['arr_1']

print(x_train.shape)
print(y_train.shape)
# Out:
# (72, 256, 256, 3)
# (72,)

# %%
data_test = np.load('Parkinson_disease_detection/test_set.npz', allow_pickle=True)
x_test = data_test['arr_0']
y_test = data_test['arr_1']

print(x_test.shape)
print(y_test.shape)
(30, 256, 256, 3)
# Out:
# (30, 256, 256, 3)
# (30,)
# (30, 256, 256, 3)

# %%
train_data_generator = ImageDataGenerator(rotation_range=360,
                                    width_shift_range=0.0,
                                    height_shift_range=0.0,
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True,
                                    vertical_flip=True)

x = list(x_train)
y = list(y_train)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=360,
                                    width_shift_range=0.0,
                                    height_shift_range=0.0,
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True,
                                    vertical_flip=True)

x = list(x_test)
y = list(y_test)

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 5040
# 5040
# 5112
# 5112
# 600
# 600
# 630
# 630

# %%
for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_train[i] = img

for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_test[i] = img

x_train = np.array(x_train)
x_test = np.array(x_test)

x_train = x_train/255.0
x_test = x_test/255.0

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(y_train.shape)

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(y_test.shape)
# Out:
# (5112,)
# (630,)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (5112, 128, 128, 1)
# (5112, 2)
# (630, 128, 128, 1)
# (630, 2)

# %%
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))

    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu',
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))

    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))

    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  fc1 (Dense)                 (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  fc3 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 238,146
# Trainable params: 238,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('acc') is not None and logs.get('acc') > ACCURACY_THRESHOLD):
          print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))
          self.model.stop_training = True

# %%
callbacks = myCallback()
ACCURACY_THRESHOLD = 0.95

# %%
hist = model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test),callbacks=[callbacks])
# Out:
# Epoch 1/100
#  6/40 [===>..........................] - ETA: 3s - loss: 0.8558 - accuracy: 0.5260
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0367s vs `on_train_batch_end` time: 0.0630s). Check your callbacks.
# 40/40 [==============================] - 24s 187ms/step - loss: 0.8547 - accuracy: 0.5063 - val_loss: 0.8480 - val_accuracy: 0.5000
# Epoch 2/100
# 40/40 [==============================] - 5s 118ms/step - loss: 0.8453 - accuracy: 0.4967 - val_loss: 0.8416 - val_accuracy: 0.5000
# Epoch 3/100
# 40/40 [==============================] - 5s 120ms/step - loss: 0.8387 - accuracy: 0.5090 - val_loss: 0.8357 - val_accuracy: 0.5000
# Epoch 4/100
# 40/40 [==============================] - 5s 114ms/step - loss: 0.8333 - accuracy: 0.4963 - val_loss: 0.8301 - val_accuracy: 0.5000
# Epoch 5/100
# 40/40 [==============================] - 5s 119ms/step - loss: 0.8273 - accuracy: 0.5033 - val_loss: 0.8238 - val_accuracy: 0.5000
# Epoch 6/100
# 40/40 [==============================] - 5s 117ms/step - loss: 0.8222 - accuracy: 0.5012 - val_loss: 0.8185 - val_accuracy: 0.5000
# Epoch 7/100
# 40/40 [==============================] - 5s 119ms/step - loss: 0.8176 - accuracy: 0.5041 - val_loss: 0.8142 - val_accuracy: 0.6397
# Epoch 8/100
# 40/40 [==============================] - 5s 121ms/step - loss: 0.8120 - accuracy: 0.5143 - val_loss: 0.8084 - val_accuracy: 0.5000
# Epoch 9/100
# 40/40 [==============================] - 5s 119ms/step - loss: 0.8073 - accuracy: 0.5149 - val_loss: 0.8041 - val_accuracy: 0.5000
# Epoch 10/100
# 40/40 [==============================] - 5s 120ms/step - loss: 0.8034 - accuracy: 0.5178 - val_loss: 0.7993 - val_accuracy: 0.5032
# Epoch 11/100
# 40/40 [==============================] - 5s 123ms/step - loss: 0.7984 - accuracy: 0.5282 - val_loss: 0.7945 - val_accuracy: 0.5000
# Epoch 12/100
# 40/40 [==============================] - 5s 119ms/step - loss: 0.7943 - accuracy: 0.5243 - val_loss: 0.7892 - val_accuracy: 0.6810
# Epoch 13/100
# 40/40 [==============================] - 5s 122ms/step - loss: 0.7901 - accuracy: 0.5272 - val_loss: 0.7840 - val_accuracy: 0.5000
# Epoch 14/100
# 40/40 [==============================] - 5s 125ms/step - loss: 0.7856 - accuracy: 0.5409 - val_loss: 0.7772 - val_accuracy: 0.6714
# Epoch 15/100
# 40/40 [==============================] - 5s 123ms/step - loss: 0.7812 - accuracy: 0.5423 - val_loss: 0.7787 - val_accuracy: 0.6714
# Epoch 16/100
# 40/40 [==============================] - 5s 119ms/step - loss: 0.7762 - accuracy: 0.5575 - val_loss: 0.7676 - val_accuracy: 0.6968
# Epoch 17/100
# 40/40 [==============================] - 5s 122ms/step - loss: 0.7717 - accuracy: 0.5687 - val_loss: 0.7608 - val_accuracy: 0.7063
# Epoch 18/100
# 40/40 [==============================] - 5s 124ms/step - loss: 0.7656 - accuracy: 0.5837 - val_loss: 0.7563 - val_accuracy: 0.7063
# Epoch 19/100
# 40/40 [==============================] - 5s 124ms/step - loss: 0.7614 - accuracy: 0.5923 - val_loss: 0.7483 - val_accuracy: 0.7603
# Epoch 20/100
# 40/40 [==============================] - 5s 122ms/step - loss: 0.7558 - accuracy: 0.6092 - val_loss: 0.7409 - val_accuracy: 0.7571
# Epoch 21/100
# 40/40 [==============================] - 5s 121ms/step - loss: 0.7460 - accuracy: 0.6236 - val_loss: 0.7304 - val_accuracy: 0.7698
# Epoch 22/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.7358 - accuracy: 0.6522 - val_loss: 0.7229 - val_accuracy: 0.8000
# Epoch 23/100
# 40/40 [==============================] - 5s 127ms/step - loss: 0.7304 - accuracy: 0.6622 - val_loss: 0.7157 - val_accuracy: 0.7556
# Epoch 24/100
# 40/40 [==============================] - 5s 123ms/step - loss: 0.7174 - accuracy: 0.6719 - val_loss: 0.7065 - val_accuracy: 0.7873
# Epoch 25/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.7052 - accuracy: 0.6831 - val_loss: 0.7008 - val_accuracy: 0.7635
# Epoch 26/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.6952 - accuracy: 0.6942 - val_loss: 0.6922 - val_accuracy: 0.7651
# Epoch 27/100
# 40/40 [==============================] - 5s 124ms/step - loss: 0.6797 - accuracy: 0.7124 - val_loss: 0.6866 - val_accuracy: 0.7492
# Epoch 28/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.6658 - accuracy: 0.7177 - val_loss: 0.6707 - val_accuracy: 0.7619
# Epoch 29/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.6575 - accuracy: 0.7340 - val_loss: 0.6673 - val_accuracy: 0.7556
# Epoch 30/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.6426 - accuracy: 0.7388 - val_loss: 0.6635 - val_accuracy: 0.7222
# Epoch 31/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.6370 - accuracy: 0.7422 - val_loss: 0.6727 - val_accuracy: 0.6825
# Epoch 32/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.6205 - accuracy: 0.7525 - val_loss: 0.6717 - val_accuracy: 0.6587
# Epoch 33/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.6149 - accuracy: 0.7514 - val_loss: 0.6524 - val_accuracy: 0.7127
# Epoch 34/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.6093 - accuracy: 0.7590 - val_loss: 0.6507 - val_accuracy: 0.7000
# Epoch 35/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.5989 - accuracy: 0.7700 - val_loss: 0.6339 - val_accuracy: 0.7381
# Epoch 36/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5844 - accuracy: 0.7760 - val_loss: 0.6259 - val_accuracy: 0.7619
# Epoch 37/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.5828 - accuracy: 0.7784 - val_loss: 0.6210 - val_accuracy: 0.7698
# Epoch 38/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.5748 - accuracy: 0.7774 - val_loss: 0.6309 - val_accuracy: 0.7079
# Epoch 39/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.5622 - accuracy: 0.7844 - val_loss: 0.6049 - val_accuracy: 0.7857
# Epoch 40/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5589 - accuracy: 0.7872 - val_loss: 0.6015 - val_accuracy: 0.7952
# Epoch 41/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.5526 - accuracy: 0.7881 - val_loss: 0.5954 - val_accuracy: 0.7587
# Epoch 42/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.5476 - accuracy: 0.7987 - val_loss: 0.6264 - val_accuracy: 0.6968
# Epoch 43/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5416 - accuracy: 0.7991 - val_loss: 0.5864 - val_accuracy: 0.7984
# Epoch 44/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.5349 - accuracy: 0.8059 - val_loss: 0.5718 - val_accuracy: 0.8127
# Epoch 45/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5304 - accuracy: 0.8073 - val_loss: 0.5905 - val_accuracy: 0.7587
# Epoch 46/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.5202 - accuracy: 0.8099 - val_loss: 0.6131 - val_accuracy: 0.7000
# Epoch 47/100
# 40/40 [==============================] - 5s 127ms/step - loss: 0.5164 - accuracy: 0.8134 - val_loss: 0.5974 - val_accuracy: 0.7254
# Epoch 48/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5083 - accuracy: 0.8206 - val_loss: 0.5632 - val_accuracy: 0.8048
# Epoch 49/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.5018 - accuracy: 0.8206 - val_loss: 0.6060 - val_accuracy: 0.7095
# Epoch 50/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.5023 - accuracy: 0.8206 - val_loss: 0.5545 - val_accuracy: 0.8000
# Epoch 51/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.4977 - accuracy: 0.8198 - val_loss: 0.5597 - val_accuracy: 0.7857
# Epoch 52/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.4893 - accuracy: 0.8277 - val_loss: 0.5677 - val_accuracy: 0.7492
# Epoch 53/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.4805 - accuracy: 0.8333 - val_loss: 0.5362 - val_accuracy: 0.8127
# Epoch 54/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.4760 - accuracy: 0.8341 - val_loss: 0.5353 - val_accuracy: 0.8127
# Epoch 55/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.4720 - accuracy: 0.8378 - val_loss: 0.6261 - val_accuracy: 0.6952
# Epoch 56/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.4716 - accuracy: 0.8367 - val_loss: 0.5283 - val_accuracy: 0.8238
# Epoch 57/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.4653 - accuracy: 0.8429 - val_loss: 0.5310 - val_accuracy: 0.8270
# Epoch 58/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.4646 - accuracy: 0.8388 - val_loss: 0.5277 - val_accuracy: 0.8206
# Epoch 59/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.4719 - accuracy: 0.8326 - val_loss: 0.5162 - val_accuracy: 0.8143
# Epoch 60/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.4619 - accuracy: 0.8419 - val_loss: 0.5237 - val_accuracy: 0.8302
# Epoch 61/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.4484 - accuracy: 0.8492 - val_loss: 0.5201 - val_accuracy: 0.8222
# Epoch 62/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.4451 - accuracy: 0.8484 - val_loss: 0.5257 - val_accuracy: 0.8143
# Epoch 63/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.4477 - accuracy: 0.8482 - val_loss: 0.5285 - val_accuracy: 0.8175
# Epoch 64/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.4304 - accuracy: 0.8590 - val_loss: 0.5158 - val_accuracy: 0.8254
# Epoch 65/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.4286 - accuracy: 0.8562 - val_loss: 0.4981 - val_accuracy: 0.8270
# Epoch 66/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.4218 - accuracy: 0.8582 - val_loss: 0.5384 - val_accuracy: 0.8127
# Epoch 67/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.4248 - accuracy: 0.8525 - val_loss: 0.4973 - val_accuracy: 0.8365
# Epoch 68/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.4281 - accuracy: 0.8570 - val_loss: 0.5151 - val_accuracy: 0.8302
# Epoch 69/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.4140 - accuracy: 0.8613 - val_loss: 0.5222 - val_accuracy: 0.8175
# Epoch 70/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.4119 - accuracy: 0.8613 - val_loss: 0.5163 - val_accuracy: 0.8175
# Epoch 71/100
# 40/40 [==============================] - 5s 127ms/step - loss: 0.4077 - accuracy: 0.8633 - val_loss: 0.4888 - val_accuracy: 0.8444
# Epoch 72/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.4049 - accuracy: 0.8666 - val_loss: 0.4880 - val_accuracy: 0.8381
# Epoch 73/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.3988 - accuracy: 0.8707 - val_loss: 0.4941 - val_accuracy: 0.8238
# Epoch 74/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3962 - accuracy: 0.8707 - val_loss: 0.4795 - val_accuracy: 0.8571
# Epoch 75/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3896 - accuracy: 0.8740 - val_loss: 0.4824 - val_accuracy: 0.8365
# Epoch 76/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3880 - accuracy: 0.8748 - val_loss: 0.4793 - val_accuracy: 0.8556
# Epoch 77/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.3802 - accuracy: 0.8791 - val_loss: 0.4786 - val_accuracy: 0.8333
# Epoch 78/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3729 - accuracy: 0.8805 - val_loss: 0.4894 - val_accuracy: 0.8333
# Epoch 79/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3859 - accuracy: 0.8762 - val_loss: 0.4980 - val_accuracy: 0.8365
# Epoch 80/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3673 - accuracy: 0.8797 - val_loss: 0.4827 - val_accuracy: 0.8397
# Epoch 81/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.3747 - accuracy: 0.8766 - val_loss: 0.4835 - val_accuracy: 0.8286
# Epoch 82/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.3609 - accuracy: 0.8846 - val_loss: 0.5594 - val_accuracy: 0.8270
# Epoch 83/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.3558 - accuracy: 0.8858 - val_loss: 0.4798 - val_accuracy: 0.8397
# Epoch 84/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.3567 - accuracy: 0.8860 - val_loss: 0.4499 - val_accuracy: 0.8492
# Epoch 85/100
# 40/40 [==============================] - 5s 125ms/step - loss: 0.3495 - accuracy: 0.8908 - val_loss: 0.4542 - val_accuracy: 0.8524
# Epoch 86/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3451 - accuracy: 0.8930 - val_loss: 0.4794 - val_accuracy: 0.8397
# Epoch 87/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.3448 - accuracy: 0.8912 - val_loss: 0.4926 - val_accuracy: 0.8397
# Epoch 88/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3373 - accuracy: 0.9008 - val_loss: 0.4843 - val_accuracy: 0.8476
# Epoch 89/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.3345 - accuracy: 0.9002 - val_loss: 0.4420 - val_accuracy: 0.8683
# Epoch 90/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.3425 - accuracy: 0.8963 - val_loss: 0.4321 - val_accuracy: 0.8730
# Epoch 91/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.3299 - accuracy: 0.9002 - val_loss: 0.4297 - val_accuracy: 0.8698
# Epoch 92/100
# 40/40 [==============================] - 5s 127ms/step - loss: 0.3376 - accuracy: 0.8981 - val_loss: 0.5600 - val_accuracy: 0.8286
# Epoch 93/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.3236 - accuracy: 0.9020 - val_loss: 0.4271 - val_accuracy: 0.8778
# Epoch 94/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3119 - accuracy: 0.9126 - val_loss: 0.4863 - val_accuracy: 0.8460
# Epoch 95/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.3120 - accuracy: 0.9151 - val_loss: 0.4394 - val_accuracy: 0.8778
# Epoch 96/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3068 - accuracy: 0.9120 - val_loss: 0.4131 - val_accuracy: 0.8889
# Epoch 97/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.3038 - accuracy: 0.9169 - val_loss: 0.4882 - val_accuracy: 0.8429
# Epoch 98/100
# 40/40 [==============================] - 5s 129ms/step - loss: 0.3192 - accuracy: 0.9079 - val_loss: 0.4074 - val_accuracy: 0.8937
# Epoch 99/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.2965 - accuracy: 0.9216 - val_loss: 0.5254 - val_accuracy: 0.8397
# Epoch 100/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.3142 - accuracy: 0.9085 - val_loss: 0.4140 - val_accuracy: 0.8873

# %%
figure = plt.figure(figsize=(5, 5))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(5, 5))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 20/20 [==============================] - 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88       315
#            1       0.85      0.93      0.89       315
#
#     accuracy                           0.89       630
#    macro avg       0.89      0.89      0.89       630
# weighted avg       0.89      0.89      0.89       630

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <Axes: >

# %%
model.save('/content/drive/MyDrive/Park/parkinson_detection.h5')

# %%
m = tf.keras.models.load_model('/content/drive/MyDrive/Park/parkinson_detection.h5')
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  fc1 (Dense)                 (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  fc3 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 238,146
# Trainable params: 238,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread('Parkinson_disease_detection/test_image_healthy.png')
image_parkinson = cv2.imread('Parkinson_disease_detection/test_image_parkinson.png')

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = m.predict(image_healthy)
print(ypred_healthy)
type(ypred_healthy)
ypred_parkinson = model.predict(image_parkinson)
# Out:
# 1/1 [==============================] - 0s 254ms/step
# [[1. 0.]]
# 1/1 [==============================] - 0s 99ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()

# %%
pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gradio
#   Downloading gradio-3.27.0-py3-none-any.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 81.8 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 9.0 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.5 MB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.8.10-cp39-cp39-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 17.8 MB/s eta 0:00:00
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from gradio) (1.22.4)
# Collecting gradio-client>=0.1.3
#   Downloading gradio_client-0.1.3-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.2/286.2 kB 34.6 MB/s eta 0:00:00
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (4.2.2)
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from gradio) (8.4.0)
# Collecting uvicorn
#   Downloading uvicorn-0.21.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 8.6 MB/s eta 0:00:00
# Collecting semantic-version
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from gradio) (4.5.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from gradio) (1.5.3)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio) (2.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from gradio) (6.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from gradio) (1.10.7)
# Collecting websockets>=10.0
#   Downloading websockets-11.0.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.7/129.7 kB 17.9 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.13.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 25.4 MB/s eta 0:00:00
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mdit-py-plugins<=0.3.3
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from gradio) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (2.2.0)
# Collecting fastapi
#   Downloading fastapi-0.95.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from gradio) (2.27.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from gradio-client>=0.1.3->gradio) (23.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from gradio-client>=0.1.3->gradio) (2023.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.0->gradio) (3.11.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.0->gradio) (4.65.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio) (2022.7.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (23.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 20.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 15.5 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 11.6 MB/s eta 0:00:00
# Collecting starlette<0.27.0,>=0.26.1
#   Downloading starlette-0.26.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (1.3.0)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (5.12.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->gradio) (1.26.15)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio) (8.1.3)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->gradio) (3.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->gradio) (3.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4707 sha256=e497a160bf8b794aaab03db8d939ef4205a26d0fc3b4711e414fb11e364d62e0
#   Stored in directory: /root/.cache/pip/wheels/91/e2/96/f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, uc-micro-py, semantic-version, python-multipart, orjson, multidict, h11, frozenlist, async-timeout, aiofiles, yarl, uvicorn, starlette, mdit-py-plugins, linkify-it-py, huggingface-hub, httpcore, aiosignal, httpx, fastapi, aiohttp, gradio-client, gradio
# Successfully installed aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 fastapi-0.95.1 ffmpy-0.3.0 frozenlist-1.3.3 gradio-3.27.0 gradio-client-0.1.3 h11-0.14.0 httpcore-0.17.0 httpx-0.24.0 huggingface-hub-0.13.4 linkify-it-py-2.0.0 mdit-py-plugins-0.3.3 multidict-6.0.4 orjson-3.8.10 pydub-0.25.1 python-multipart-0.0.6 semantic-version-2.10.0 starlette-0.26.1 uc-micro-py-1.0.1 uvicorn-0.21.1 websockets-11.0.2 yarl-1.9.1

# %%
import gradio as gr
image_input = gr.inputs.Image()

label_output = gr.outputs.Label(num_top_classes=1)

def classify(image_healthy):
  image_healthy = cv2.resize(image_healthy, (128, 128))
  image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
  image_healthy = np.array(image_healthy)
  image_healthy = np.expand_dims(image_healthy, axis=0)
  image_healthy = np.expand_dims(image_healthy, axis=-1)
  res = model.predict(image_healthy)
  l = labels[np.argmax(res[0], axis=0)]
  return l


gr.Interface(fn=classify, inputs=[image_input], outputs=label_output, title='Image Classification',
             description='Classify an image with threshold using my model').launch(share=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/gradio/inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.9/dist-packages/gradio/outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://bc56441313d131b206.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://bc56441313d131b206.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
